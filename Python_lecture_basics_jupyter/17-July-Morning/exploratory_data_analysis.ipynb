# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')
# pd.set_option('max_columns', 40)

# %%
df = pd.read_csv('crime2018.csv')

# %% [markdown]
# # Step 1: Understanding of the dataset
# .DataFrame Shape<br>
# .head and tail<br>
# .dtypes<br>
# .describe<br>

# %%
df.shape
# Out:
# (127, 38)

# %%
df.head()
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN   Totals Cases  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
# 3        NaN              HOMICIDES            NaN                  NaN
# 4          1   Death  (by shooting)            190                  117
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'REPORTED CASES', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'PERFOMANCE', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'PERSONS TAKEN TO COURT', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                     object
# Unnamed: 1                     object
# REPORTED CASES                 object
# Unnamed: 3                     object
# Unnamed: 4                     object
# Unnamed: 5                     object
# PERFOMANCE                     object
# Unnamed: 7                     object
# Unnamed: 8                     object
# Unnamed: 9                     object
# Unnamed: 10                    object
# PERSONS TAKEN TO COURT         object
# Unnamed: 12                    object
# Unnamed: 13                    object
# Unnamed: 14                    object
# Unnamed: 15                    object
# Unnamed: 16                    object
# Unnamed: 17                    object
# Unnamed: 18                    object
# Unnamed: 19                    object
# Unnamed: 20                    object
# Unnamed: 21                    object
# SENTENCES IMPOSED BY COURTS    object
# Unnamed: 23                    object
# Unnamed: 24                    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0             Unnamed: 1 REPORTED CASES Unnamed: 3 Unnamed: 4  \
# count          95                    125            125        125        125
# unique         95                    125            104         95         89
# top         S/No.  CASE/CRIME INCIDENCES              -          -          -
# freq            1                      1             17         18         24
#
#        Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# count         125        125        125        125        125  ...
# unique         89         98         66         41         60  ...
# top             -          -          -          -          -  ...
# freq           20         19         34         55         39  ...
#
#        Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# count          109         109         109         109         100
# unique          15          46          51          68          91
# ...

# %% [markdown]
# # Step 2: Data preparation
# -Dropping irrelevant columns and rows <br>
# -Identifying duplicated columns<br>
# -Renaming columns<br>
# -Feature creation<br>

# %%
df.head()
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN   Totals Cases  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
# 3        NaN              HOMICIDES            NaN                  NaN
# 4          1   Death  (by shooting)            190                  117
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  ...  \
# ...

# %%
df[['Unnamed: 0', 'Unnamed: 1', 'REPORTED CASES', 'Unnamed: 3',
       'Unnamed: 4', 'Unnamed: 5', 'PERFOMANCE', 'Unnamed: 7', 'Unnamed: 8',
       'Unnamed: 9', 'Unnamed: 10', 'PERSONS TAKEN TO COURT', 'Unnamed: 12',
       'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
       'Unnamed: 21', 'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23',
       'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
       'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
       'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
       'Unnamed: 36', 'Unnamed: 37']]
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0          NaN                    NaN            NaN                  NaN
# 1          NaN                    NaN   Totals Cases  Cases under Inquiry
# 2        S/No.  CASE/CRIME INCIDENCES              1                    2
# 3          NaN              HOMICIDES            NaN                  NaN
# 4            1   Death  (by shooting)            190                  117
# ..         ...                    ...            ...                  ...
# 122         98            UWA Statute            648                  112
# 123         99   Local Government Act              4                    2
# 124        100         All other Acts            821                  345
# 125        NaN  Sub Total(Other Laws)          3,006                  749
# 126        NaN            GRAND TOTAL        238,746               90,763
#
#            Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# ...

# %%
df = df.rename(columns = {
    'Unnamed: 0': 'Zero',
    'Unnamed: 1': 'One', 
    'Unnamed: 3': 'Three',
    'Unnamed: 4': 'Four', 
    'Unnamed: 5': 'Five',  
    'Unnamed: 7': 'Seven', 
    'Unnamed: 8': 'Eight',
    'Unnamed: 9': 'Nine', 
    'Unnamed: 10': 'Ten',
    'Unnamed: 12': 'Twelve',
    'Unnamed: 13': 'Thirteen', 
    'Unnamed: 14': 'Fourteen', 
    'Unnamed: 15': 'Fiftee', 
    'Unnamed: 16': 'Sixteen',
    'Unnamed: 17': 'Seventeen', 
    'Unnamed: 18': 'Eighteen',
    'Unnamed: 19': 'Nineteen', 
    'Unnamed: 20': 'Twenty',
    'Unnamed: 21': 'Twenty_One', 
    'Unnamed: 23': 'Twenty_Three',
    'Unnamed: 24': 'Twenty_Four', 
    'Unnamed: 25': 'Twenty_Five', 
    'Unnamed: 26': 'Twenty_, Six',
    'Unnamed: 27': 'Twenty_Seven',
    'Unnamed: 28': 'Twenty_Eight', 
    'Unnamed: 29': 'Twenty_Nine', 
    'Unnamed: 30': 'Thirty', 
    'Unnamed: 31': 'Thirty_One',
    'Unnamed: 32': 'Thirty_Two', 
    'Unnamed: 33': 'Thirty_Three', 
    'Unnamed: 34': 'Thirty_Four', 
    'Unnamed: 35': 'Thirty_Five',
    'Unnamed: 36': 'Thirty_Six', 
    'Unnamed: 37': 'Thirty_Seven'
})

# %%
df.isna().sum()
# Out:
# Zero                           32
# One                             2
# REPORTED CASES                  2
# Three                           2
# Four                            2
# Five                            2
# PERFOMANCE                      2
# Seven                           2
# Eight                           2
# Nine                            2
# Ten                             2
# PERSONS TAKEN TO COURT          1
# Twelve                          3
# Thirteen                        3
# Fourteen                        3
# Fiftee                          1
# Sixteen                         3
# Seventeen                       3
# Eighteen                        3
# Nineteen                       18
# Twenty                         18
# Twenty_One                     18
# SENTENCES IMPOSED BY COURTS    18
# Twenty_Three                   19
# Twenty_Four                    19
# Twenty_Five                    18
# Twenty_, Six                   18
# ...

# %%
df.loc[~df.duplicated(subset=['One', 'Five', 'Twenty_Five', 'Thirty_Four'])]
# Out:
#       Zero                    One REPORTED CASES                Three  \
# 0      NaN                    NaN            NaN                  NaN
# 1      NaN                    NaN   Totals Cases  Cases under Inquiry
# 2    S/No.  CASE/CRIME INCIDENCES              1                    2
# 3      NaN              HOMICIDES            NaN                  NaN
# 4        1   Death  (by shooting)            190                  117
# ..     ...                    ...            ...                  ...
# 122     98            UWA Statute            648                  112
# 123     99   Local Government Act              4                    2
# 124    100         All other Acts            821                  345
# 125    NaN  Sub Total(Other Laws)          3,006                  749
# 126    NaN            GRAND TOTAL        238,746               90,763
#
#                  Four                  Five                 PERFOMANCE  \
# ...

# %%
df.drop_duplicates()
# Out:
#       Zero                    One REPORTED CASES                Three  \
# 0      NaN                    NaN            NaN                  NaN
# 1      NaN                    NaN   Totals Cases  Cases under Inquiry
# 2    S/No.  CASE/CRIME INCIDENCES              1                    2
# 3      NaN              HOMICIDES            NaN                  NaN
# 4        1   Death  (by shooting)            190                  117
# ..     ...                    ...            ...                  ...
# 122     98            UWA Statute            648                  112
# 123     99   Local Government Act              4                    2
# 124    100         All other Acts            821                  345
# 125    NaN  Sub Total(Other Laws)          3,006                  749
# 126    NaN            GRAND TOTAL        238,746               90,763
#
#                  Four                  Five                 PERFOMANCE  \
# ...

# %%
df = df.fillna('')
df
# Out:
#       Zero                    One REPORTED CASES                Three  \
# 0
# 1                                   Totals Cases  Cases under Inquiry
# 2    S/No.  CASE/CRIME INCIDENCES              1                    2
# 3                       HOMICIDES
# 4        1   Death  (by shooting)            190                  117
# ..     ...                    ...            ...                  ...
# 122     98            UWA Statute            648                  112
# 123     99   Local Government Act              4                    2
# 124    100         All other Acts            821                  345
# 125         Sub Total(Other Laws)          3,006                  749
# 126                   GRAND TOTAL        238,746               90,763
#
#                  Four                  Five                 PERFOMANCE  \
# 0
# 1    Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                   3                     4                          5
# 3
# ...

# %%
for x in df.index:
    if df.loc[x, "One"] == '':
        df.drop(x, inplace=True)
        
df
# Out:
#       Zero                    One REPORTED CASES   Three    Four    Five  \
# 2    S/No.  CASE/CRIME INCIDENCES              1       2       3       4
# 3                       HOMICIDES
# 4        1   Death  (by shooting)            190     117      29      44
# 5        2  Death (by mob action)            636     431     109      96
# 6        3      Death (Poisoning)             81      54      12      15
# ..     ...                    ...            ...     ...     ...     ...
# 122     98            UWA Statute            648     112      89     447
# 123     99   Local Government Act              4       2       1       1
# 124    100         All other Acts            821     345     189     287
# 125         Sub Total(Other Laws)          3,006     749     620   1,637
# 126                   GRAND TOTAL        238,746  90,763  74,948  73,035
#
#     PERFOMANCE   Seven  Eight    Nine  ... Twenty_Eight Twenty_Nine Thirty  \
# ...

# %%
for x in df.index:
    if df.loc[x, "Zero"] == '':
        df.drop(x, inplace=True)
        
df
# Out:
#       Zero                                   One REPORTED CASES Three Four  \
# 2    S/No.                 CASE/CRIME INCIDENCES              1     2    3
# 4        1                  Death  (by shooting)            190   117   29
# 5        2                 Death (by mob action)            636   431  109
# 6        3                     Death (Poisoning)             81    54   12
# 7        4  Death (Aggravated Domestic Violence)            362   107   24
# ..     ...                                   ...            ...   ...  ...
# 120     96                          Firearms Act            109    38   23
# 121     97                            Enguli Act              4     3    1
# 122     98                           UWA Statute            648   112   89
# 123     99                  Local Government Act              4     2    1
# 124    100                        All other Acts            821   345  189
#
# ...

# %%
for x in df.index:
    if df.loc[x, "REPORTED CASES"] == '':
        df.drop(x, inplace=True)
        
df
# Out:
#       Zero                                   One REPORTED CASES Three Four  \
# 2    S/No.                 CASE/CRIME INCIDENCES              1     2    3
# 4        1                  Death  (by shooting)            190   117   29
# 5        2                 Death (by mob action)            636   431  109
# 6        3                     Death (Poisoning)             81    54   12
# 7        4  Death (Aggravated Domestic Violence)            362   107   24
# ..     ...                                   ...            ...   ...  ...
# 120     96                          Firearms Act            109    38   23
# 121     97                            Enguli Act              4     3    1
# 122     98                           UWA Statute            648   112   89
# 123     99                  Local Government Act              4     2    1
# 124    100                        All other Acts            821   345  189
#
# ...

# %%
df.reset_index(drop=True)
# Out:
#      Zero                                   One REPORTED CASES Three Four  \
# 0   S/No.                 CASE/CRIME INCIDENCES              1     2    3
# 1       1                  Death  (by shooting)            190   117   29
# 2       2                 Death (by mob action)            636   431  109
# 3       3                     Death (Poisoning)             81    54   12
# 4       4  Death (Aggravated Domestic Violence)            362   107   24
# ..    ...                                   ...            ...   ...  ...
# 90     96                          Firearms Act            109    38   23
# 91     97                            Enguli Act              4     3    1
# 92     98                           UWA Statute            648   112   89
# 93     99                  Local Government Act              4     2    1
# 94    100                        All other Acts            821   345  189
#
#    Five PERFOMANCE Seven Eight Nine  ... Twenty_Eight Twenty_Nine Thirty  \
# ...
