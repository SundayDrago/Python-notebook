# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
#indeed.com->
#appwork.com->
#coursera.org->
x = [1,3,3,1], x
y = [1,1,4,4]
plt.plot(x,y,'o')
plt.xlabel("x")
plt.ylabel("y")
plt.show()
