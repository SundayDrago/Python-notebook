# %%
import numpy as py
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Control Display of seaborn - optimal
pd.options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"#CAF1DE"})

# %%
# Loading dataset
df = pd.read_csv('uceresult.csv')
df
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
# Understanding of the data structure
# Checking the shape of the data- understanding the rows and columns
df.shape
# Out:
# (17639, 48)

# %%
# Checking of the columns name
df.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
# Data preparation and preprocessing
# Data cleaning- Data cleaning, wrong data, wrong format,null values, duplicate values
# Columns like 'District', FEMALE TOTAL DIV1, FEMALE% X etc contain white spaces at the end.
# Clean the column names using the code below
df.columns = df.columns.to_series().apply(lambda x: x.strip())

# %%
# DataFrame columns after removing the white space
df.columns
# Out:
# Index(['YEAR', 'DISTRICT', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1',
#        'FEMALE % DIV1', 'FEMALE TOTAL DIV2', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1', 'MALE % DIV1', 'MALE TOTAL DIV2',
#        'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3', 'MALE TOTAL DIV4',
#        'MALE % DIV4', 'MALE TOTAL DIV7', 'MALE % DIV7', 'MALE TOTAL DIV9',
#        'MALE % DIV9', 'MALE TOTAL X', 'MALE % X'],
#       dtype='object')

# %%
# Replace white spaces with underscores for every columns
df.columns = df.columns.str.replace('','_')
df.columns
# Out:
# Index(['___Y___E___A___R___', '___D___I___S___T___R___I___C___T___',
#        '___S___C___H___O___O___L___',
#        '___T___O___T___A___L_______C___A___N___D___I___D___A___T___E___S___',
#        '___T___O___T___A___L_______D___I___V_______1___',
#        '___%_______D___I___V_______1___',
#        '___T___O___T___A___L_______D___I___V_______2___',
#        '___%_______D___I___V_______2___',
#        '___T___O___T___A___L_______D___I___V_______3___',
#        '___%_______D___I___V_______3___',
#        '___T___O___T___A___L_______D___I___V_______4___',
#        '___%_______D___I___V_______4___',
#        '___T___O___T___A___L_______D___I___V_______7___',
#        '___%_______D___I___V_______7___',
#        '___T___O___T___A___L_______D___I___V_______9___',
#        '___%_______D___I___V_______9___', '___T___O___T___A___L_______X___',
#        '___%_______X___',
#        '___F___E___M___A___L___E_______C___A___N___D___I___D___A___T___E___S___',
# ...

# %%
# Checking for the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17639 entries, 0 to 17638
# Data columns (total 48 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   _Y_E_A_R_                            17639 non-null  int64
#  1   _D_I_S_T_R_I_C_T_                    17639 non-null  object
#  2   _S_C_H_O_O_L_                        17638 non-null  object
#  3   _T_O_T_A_L_ _C_A_N_D_I_D_A_T_E_S_    17368 non-null  float64
#  4   _T_O_T_A_L_ _D_I_V_ _1_              12858 non-null  float64
#  5   _%_ _D_I_V_ _1_                      17639 non-null  float64
#  6   _T_O_T_A_L_ _D_I_V_ _2_              16880 non-null  float64
#  7   _%_ _D_I_V_ _2_                      17639 non-null  float64
#  8   _T_O_T_A_L_ _D_I_V_ _3_              17168 non-null  float64
#  9   _%_ _D_I_V_ _3_                      17639 non-null  float64
#  10  _T_O_T_A_L_ _D_I_V_ _4_              16888 non-null  float64
# ...
