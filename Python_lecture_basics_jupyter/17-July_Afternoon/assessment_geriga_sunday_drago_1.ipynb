# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('crime2018.csv')

# %%
df.head(10)
# Out:
#   Unnamed: 0                            Unnamed: 1 REPORTED CASES  \
# 0        NaN                                   NaN            NaN
# 1        NaN                                   NaN   Totals Cases
# 2      S/No.                 CASE/CRIME INCIDENCES              1
# 3        NaN                             HOMICIDES            NaN
# 4          1                  Death  (by shooting)            190
# 5          2                 Death (by mob action)            636
# 6          3                     Death (Poisoning)             81
# 7          4  Death (Aggravated Domestic Violence)            362
# 8          5                Death(Fire Out Breaks)             42
# 9          8     Other Death (Not Specified above)          3,186
#
#             Unnamed: 3        Unnamed: 4            Unnamed: 5  \
# 0                  NaN               NaN                   NaN
# 1  Cases under Inquiry  Not Detected/NPW  Cases taken to court
# ...

# %%
df.tail(10)
# Out:
#     Unnamed: 0               Unnamed: 1 REPORTED CASES Unnamed: 3 Unnamed: 4  \
# 117         93          Immigration Act            472         45         84
# 118         94                     NEMA            306        113         78
# 119         95  Fish and Crocodiles Act            642         91        155
# 120         96             Firearms Act            109         38         23
# 121         97               Enguli Act              4          3          1
# 122         98              UWA Statute            648        112         89
# 123         99     Local Government Act              4          2          1
# 124        100           All other Acts            821        345        189
# 125        NaN    Sub Total(Other Laws)          3,006        749        620
# 126        NaN              GRAND TOTAL        238,746     90,763     74,948
#
#     Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28  \
# ...

# %%
#duplicates
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# Length: 127, dtype: bool

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# Unnamed: 1                     0
# REPORTED CASES                 0
# Unnamed: 3                     0
# Unnamed: 4                     0
# Unnamed: 5                     0
# PERFOMANCE                     0
# Unnamed: 7                     0
# Unnamed: 8                     0
# Unnamed: 9                     0
# Unnamed: 10                    0
# PERSONS TAKEN TO COURT         0
# Unnamed: 12                    0
# Unnamed: 13                    0
# Unnamed: 14                    0
# Unnamed: 15                    0
# Unnamed: 16                    0
# Unnamed: 17                    0
# Unnamed: 18                    0
# Unnamed: 19                    0
# Unnamed: 20                    0
# Unnamed: 21                    0
# SENTENCES IMPOSED BY COURTS    0
# Unnamed: 23                    0
# Unnamed: 24                    0
# Unnamed: 25                    0
# Unnamed: 26                    0
# Unnamed: 27                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   95 non-null     object
#  1   Unnamed: 1                   125 non-null    object
#  2   REPORTED CASES               125 non-null    object
#  3   Unnamed: 3                   125 non-null    object
#  4   Unnamed: 4                   125 non-null    object
#  5   Unnamed: 5                   125 non-null    object
#  6   PERFOMANCE                   125 non-null    object
#  7   Unnamed: 7                   125 non-null    object
#  8   Unnamed: 8                   125 non-null    object
#  9   Unnamed: 9                   125 non-null    object
#  10  Unnamed: 10                  125 non-null    object
#  11  PERSONS TAKEN TO COURT       126 non-null    object
#  12  Unnamed: 12                  124 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0            Unnamed: 1 REPORTED CASES Unnamed: 3 Unnamed: 4  \
# count          83                    83             83         83         83
# unique         83                    83             79         74         66
# top             1  Death  (by shooting)              4          3          -
# freq            1                     1              4          3          8
#
#        Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# count          83         83         83         83         83  ...
# unique         66         74         49         28         44  ...
# top             -          -          -          -          -  ...
# freq            5          4         17         35         21  ...
#
#        Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# count           83          83          83          83          83
# unique           9          32          36          52          77
# ...

# %%
unique_values = df['Unnamed: 1'].unique()
for value in unique_values:
    print(value)
# Out:
# nan
# CASE/CRIME INCIDENCES
# HOMICIDES
# Death  (by shooting)
# Death (by mob action)
# Death (Poisoning)
# Death (Aggravated Domestic Violence)
# Death(Fire Out Breaks)
# Other Death (Not Specified above)
# Sub Total(Homicides)
# ECONOMIC CRIMES
# Embezzlement
# Causing Financial losss
# Abuse of office
# Counterfeiting
# Forgeries & Uttering of Documents
# Issuing False Cheques
# Bank and Other Corporate Frauds
# Obtaining By False Pretences
# Cyber (Computer) crimes
# Land Frauds
# Other Economic crimes
# Sub Total(Economic crimes)
# GENERAL CRIMES
# (a) Sex Related Offences
# Rape
# Defilement
# Indecent Assault
# Incest
# Unnatural Offences
# Sub Total(Sex Related)
# (b) Child Related Offences
# Child Neglect
# Child Desertion
# Child Stealing
# Child Trafficking
# Child Abduction/Kidnap
# Child Abuse/Torture
# Infanticide
# Abortion
# Sub Total(Child Related)
# (c ) Breakings
# Burglaries
# House Breakings
# Shop Breaking
# Office Breaking
# Other Breakings (garage ,etc )
# ...

# %%
df.dropna(inplace=True)

# %%
df2 = pd.read_csv('uceresult.csv')

# %%
# Replace column names with underscore
df2.columns = df2.columns.str.replace(' ','_')
df2.columns
# Out:
# Index(['YEAR', 'DISTRICT_', 'SCHOOL', 'TOTAL_CANDIDATES', 'TOTAL_DIV_1',
#        '%_DIV_1', 'TOTAL_DIV_2', '%_DIV_2', 'TOTAL_DIV_3', '%_DIV_3',
#        'TOTAL_DIV_4', '%_DIV_4', 'TOTAL_DIV_7', '%_DIV_7', 'TOTAL_DIV_9',
#        '%_DIV_9', 'TOTAL_X', '%_X', 'FEMALE_CANDIDATES', 'FEMALE_TOTAL_DIV1_',
#        'FEMALE_%_DIV1_', 'FEMALE_TOTAL_DIV2_', 'FEMALE_%_DIV2',
#        'FEMALE_TOTAL_DIV3', 'FEMALE_%_DIV3', 'FEMALE_TOTAL_DIV4',
#        'FEMALE_%_DIV4', 'FEMALE_TOTAL_DIV7', 'FEMALE_%_DIV7',
#        'FEMALE_TOTAL_DIV9', 'FEMALE_%_DIV9', 'FEMALE_TOTAL_X', 'FEMALE_%_X_',
#        'MALE_CANDIDATES', 'MALE_TOTAL_DIV1_', 'MALE_%_DIV1_',
#        'MALE_TOTAL_DIV2_', 'MALE_%_DIV2', 'MALE_TOTAL_DIV3', 'MALE_%_DIV3',
#        'MALE_TOTAL_DIV4', 'MALE_%_DIV4_', 'MALE_TOTAL_DIV7_', 'MALE_%_DIV7',
#        'MALE_TOTAL_DIV9_', 'MALE_%_DIV9', 'MALE_TOTAL_X_', 'MALE_%_X'],
#       dtype='object')

# %%
df2.isnull().any()
# Out:
# YEAR                  False
# DISTRICT_             False
# SCHOOL                 True
# TOTAL_CANDIDATES       True
# TOTAL_DIV_1            True
# %_DIV_1               False
# TOTAL_DIV_2            True
# %_DIV_2               False
# TOTAL_DIV_3            True
# %_DIV_3               False
# TOTAL_DIV_4            True
# %_DIV_4               False
# TOTAL_DIV_7            True
# %_DIV_7               False
# TOTAL_DIV_9            True
# %_DIV_9               False
# TOTAL_X                True
# %_X                   False
# FEMALE_CANDIDATES     False
# FEMALE_TOTAL_DIV1_     True
# FEMALE_%_DIV1_         True
# FEMALE_TOTAL_DIV2_     True
# FEMALE_%_DIV2          True
# FEMALE_TOTAL_DIV3      True
# FEMALE_%_DIV3          True
# FEMALE_TOTAL_DIV4      True
# FEMALE_%_DIV4          True
# FEMALE_TOTAL_DIV7      True
# FEMALE_%_DIV7          True
# FEMALE_TOTAL_DIV9      True
# FEMALE_%_DIV9          True
# FEMALE_TOTAL_X         True
# FEMALE_%_X_            True
# ...

# %%
df2.head(10)
# Out:
#    YEAR      DISTRICT_                              SCHOOL  TOTAL_CANDIDATES  \
# 0  2011         WAKISO                  GAYAZA HIGH SCHOOL             176.0
# 1  2011         MUKONO                  NAMILYANGO COLLEGE             151.0
# 2  2011         MUKONO              MT.ST.MARY'S,NAMAGUNGA             153.0
# 3  2011         WAKISO         UGANDA MARTYRS SS,NAMUGONGO             222.0
# 4  2011  BUSHENYI MAIN                     KITABI SEMINARY              73.0
# 5  2011    MASAKA MAIN           ST.HENRY'S COLLEGE,KITOVU             164.0
# 6  2011         WAKISO                 KING'S COLLEGE,BUDO             218.0
# 7  2011        KIBAALE          NOTRE DAME ACADEMY,BUSEESA              25.0
# 8  2011        KAMPALA           ST.JOSEPH'S GIRLS,NSAMBYA             192.0
# 9  2011         WAKISO  ST.MARY'S SECONDARY SCHOOL,KITENDE             440.0
#
#    TOTAL_DIV_1  %_DIV_1  TOTAL_DIV_2  %_DIV_2  TOTAL_DIV_3  %_DIV_3  ...  \
# ...

# %%
df2.tail(10)
# Out:
#        YEAR DISTRICT_                                             SCHOOL  \
# 17629  2016     YUMBE      APO SEED SECONDARY SCHOOL    P.O.BOX 54 YUMBE
# 17630  2016     ZOMBO  ST.ALOYSIUS COLLEGE,NYAPEA    P.O.BOX 71 PAIDH...
# 17631  2016     ZOMBO  WARR GIRLS' SECONDARY SCHOOL    P.O.BOX 15 PAI...
# 17632  2016     ZOMBO       ALUKA SECONDARY SCHOOL    P.O.BOX 119 PAIDHA
# 17633  2016     ZOMBO   ZEU SECONDARY SCHOOL    P.O.BOX 159 PAIDHA-NEBBI
# 17634  2016     ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016     ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016     ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016     ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016     ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
#        TOTAL_CANDIDATES  TOTAL_DIV_1  %_DIV_1  TOTAL_DIV_2  %_DIV_2  \
# 17629              18.0          0.0      0.0          0.0      0.0
# ...

# %%
df2.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17634    False
# 17635    False
# 17636    False
# 17637    False
# 17638    False
# Length: 17639, dtype: bool

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17639 entries, 0 to 17638
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   YEAR                17639 non-null  int64
#  1   DISTRICT_           17639 non-null  object
#  2   SCHOOL              17638 non-null  object
#  3   TOTAL_CANDIDATES    17368 non-null  float64
#  4   TOTAL_DIV_1         12858 non-null  float64
#  5   %_DIV_1             17639 non-null  float64
#  6   TOTAL_DIV_2         16880 non-null  float64
#  7   %_DIV_2             17639 non-null  float64
#  8   TOTAL_DIV_3         17168 non-null  float64
#  9   %_DIV_3             17639 non-null  float64
#  10  TOTAL_DIV_4         16888 non-null  float64
#  11  %_DIV_4             17639 non-null  float64
#  12  TOTAL_DIV_7         6489 non-null   float64
#  13  %_DIV_7             17639 non-null  float64
#  14  TOTAL_DIV_9         13454 non-null  float64
# ...

# %%
df2.isnull().sum().sort_values(ascending= False)
# Out:
# FEMALE_TOTAL_DIV7     12875
# TOTAL_DIV_7           11150
# MALE_TOTAL_DIV7_      10131
# FEMALE_TOTAL_DIV1_     9114
# MALE_TOTAL_DIV1_       7601
# MALE_TOTAL_X_          7260
# MALE_TOTAL_DIV9_       7120
# FEMALE_TOTAL_X         7043
# FEMALE_TOTAL_DIV9      5290
# TOTAL_DIV_1            4781
# TOTAL_X                4235
# TOTAL_DIV_9            4185
# FEMALE_TOTAL_DIV2_     3307
# MALE_TOTAL_DIV2_       2397
# MALE_TOTAL_DIV4        1379
# MALE_TOTAL_DIV3        1240
# FEMALE_TOTAL_DIV3      1165
# FEMALE_TOTAL_DIV4       958
# TOTAL_DIV_2             759
# TOTAL_DIV_4             751
# TOTAL_DIV_3             471
# TOTAL_CANDIDATES        271
# MALE_%_DIV4_            134
# MALE_%_DIV3             134
# MALE_%_DIV7             134
# MALE_%_DIV2             134
# MALE_%_DIV1_            134
# MALE_%_DIV9             134
# MALE_%_X                134
# FEMALE_%_X_              58
# FEMALE_%_DIV3            58
# FEMALE_%_DIV9            58
# FEMALE_%_DIV4            58
# ...

# %%
div1_2011 = df2[df2['YEAR'] == 2011]['TOTAL_DIV_1'].sum()
print("Divsion Ones in 2011: ", div1_2011)
div1_2012 = df2[df2['YEAR'] == 2012]['TOTAL_DIV_1'].sum()
print("Divsion Ones in 2012: ", div1_2012)
div1_2013 = df2[df2['YEAR'] == 2013]['TOTAL_DIV_1'].sum()
print("Divsion Ones in 2013: ", div1_2013)
div1_2014 = df2[df2['YEAR'] == 2014]['TOTAL_DIV_1'].sum()
print("Divsion Ones in 2014: ", div1_2014)
div1_2015 = df2[df2['YEAR'] == 2015]['TOTAL_DIV_1'].sum()
print("Divsion Ones in 2015: ", div1_2015)
div1_2016 = df2[df2['YEAR'] == 2016]['TOTAL_DIV_1'].sum()
print("Divsion Ones in 2016: ", div1_2016)
# Out:
# Divsion Ones in 2011:  22651.0
# Divsion Ones in 2012:  18852.0
# Divsion Ones in 2013:  19951.0
# Divsion Ones in 2014:  23034.0
# Divsion Ones in 2015:  25081.0
# Divsion Ones in 2016:  23489.0

# %%
# DRAW LINE GRAPH FOR THE PERFORMANCE BASE ON
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 # DRAW LINE GRAPH FOR THE PERFORMANCE BASE ON
#       2 # FIRST FILTER THE RESULT BASE ON DIVISION 1, DIVISION 2 AND DIVISION 3
# ----> 3 plt.plot(div1_2011['YEAR'], div1_2011['Result'], label='Division One')
#       4 plt.plot(div1_2012['YEAR'], div1_2012['Result'], label='Division One')
#       5 plt.plot(div1_2013['YEAR'], div1_2013['Result'], label='Division One')
#
# IndexError: invalid index to scalar variable.

# %%
label
